# %% [markdown]
# # PhI Full PPI network analysis
# Arabidopsis PhI_Full Protein-Protein Interaction network analysis
# Ollivier-Ricci community detection with side information

# %%
# %matplotlib inline

import sys; sys.path.insert(0, "..")

import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

import collections
from math import log

# import time
import pickle

# from random import sample
from communityDetection.orcci import *
from utils.pobsnet_sinfo import *

from sklearn.metrics import normalized_mutual_info_score
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;

# %%
verbose = "TRACE"

filename = "../data/PhIFull/BIOGRID_Altman2020_32612234.xlsx"

df = pd.read_excel(filename)

gene1_label = "Systematic Name Interactor A"
gene2_label = "Systematic Name Interactor B"
g = nx.from_pandas_edgelist(df,source=gene1_label,target=gene2_label)
g.name = 'Arabidopsis PPI'

# %%
print(nx.info(g))
print("Number of connected components:", nx.number_connected_components(g), "\n")

edge_selfloops = [e1 for e1, e2 in nx.selfloop_edges(g)]
g.remove_edges_from(nx.selfloop_edges(g))

print("<<< Without self loops >>>")
print(nx.info(g))
print("Number of self loops:", len(edge_selfloops))

# degree list
degree_list = sorted(g.degree, key=lambda x: x[1], reverse=True)
print("Top 5 highest degree nodes:", degree_list[0:5])
# Out:
# Name: Arabidopsis PPI
# Type: Graph
# Number of nodes: 925
# Number of edges: 2072
# Average degree:   4.4800
# Number of connected components: 40
#
# <<< Without self loops >>>
# Name: Arabidopsis PPI
# Type: Graph
# Number of nodes: 925
# Number of edges: 2021
# Average degree:   4.3697
# Number of self loops: 51
# Top 5 highest degree nodes: [('AT4G37260', 117), ('AT4G32570', 99), ('AT1G31880', 83), ('AT1G69690', 53), ('AT1G04250', 51)]

# %% [markdown]
# ### Side Information (Global)

# %%
filename = "../data/PhIFull/Phi_Full_ppi_all_sideinfo_KEGG_edit.xlsx"

df_sinfo = pd.read_excel(filename,header=0) # ,index_col=1
df_sinfo = df_sinfo[['Label','SideInfo_Label']]
df_sinfo = df_sinfo[[isinstance(x,str) for x in df_sinfo['SideInfo_Label']]]  # filter row with valid SideInfo
pathway_list = list(set(df_sinfo['SideInfo_Label']))
pathway_list.sort()
pathway_list.insert(0,'unknown')
print("Amount of SideInfo: %d" % len(df_sinfo))
print("Number of known pathways: %d" % (len(pathway_list)-1))
print("Pathways:", pathway_list[1:])
# Out:
# Amount of SideInfo: 321
# Number of known pathways: 18
# Pathways: ['abscisic acid', 'amino acid metabolism', 'auxin', 'brassinosteroid', 'circadian rhythm', 'cytokinin', 'dna repair', 'dna rna metabolism', 'ethylene', 'fatty acid metabolism', 'gibberellin', 'jasmonic acid', 'metabolism', 'plant pathogen interaction', 'protein processing', 'rna processing', 'salicylic acid', 'signal transduction']

# %%
# label nodes with known pathways
nx.set_node_attributes(g, 'unknown', "pathway")
nx.set_node_attributes(g, 0, "pathwayID")

for idx, row  in df_sinfo.iterrows():
    gene = row['Label']
    sinfo_label = row['SideInfo_Label']
    path_id = pathway_list.index(sinfo_label)
    g.nodes[gene]['pathway'] = sinfo_label
    g.nodes[gene]['pathwayID'] = path_id

# %%
# create side information list

# check if known nodes belonging to the same community have connection
known_partition = dict()  # {0: [], 1: [], 2: []}

edges_known = []  # list of all edges known (both existing and artificially created)
nodes_known = list(df_sinfo['Label'])
for i in nodes_known:
    block = g.nodes[i]['pathway']
    insert_to_dict_list(known_partition, block, i)
    # known_partition[block].append(i)
    # print(i, block)

print("Side Info Summary:")
print("Total side information: %d" % len(nodes_known))
for i in known_partition:
    print(i, len(known_partition[i]))
    
edges_known = []
# Out:
# Side Info Summary:
# Total side information: 321
# auxin 65
# rna processing 25
# abscisic acid 55
# ethylene 36
# brassinosteroid 17
# salicylic acid 22
# gibberellin 20
# jasmonic acid 22
# cytokinin 15
# protein processing 24
# dna rna metabolism 3
# dna repair 2
# fatty acid metabolism 5
# metabolism 2
# signal transduction 3
# amino acid metabolism 3
# plant pathogen interaction 1
# circadian rhythm 1

# %%
for pathway_type in known_partition:
    pathway_gene_list = known_partition[pathway_type]
    for idx1, gene1 in enumerate(pathway_gene_list):
        for idx2, gene2 in enumerate(pathway_gene_list[idx1+1:]):
                
            # Trial # 2: Soft force of weight to maximum (and ORC)
            if g.has_edge(gene1,gene2):
                edges_known.append((gene1, gene2))
                # g.edges[(gene1, gene2)][''] = 1.0  # unweighted
        
print("Known edges:")
# print(edges_known)
print("Number of known edges:", len(edges_known))
# Out:
# Known edges:
# Number of known edges: 390

# %%
print(nx.info(g))

for idx, node in enumerate(g.nodes()):
    print(idx, node, g.nodes[node])
    if idx == 5:
        break
    
# for idx, edge in enumerate(g.edges()):
#     print(idx, edge, g.edges[edge])
#     if idx == 5:
#         break
# Out:
# Name: Arabidopsis PPI
# Type: Graph
# Number of nodes: 925
# Number of edges: 2021
# Average degree:   4.3697
# 0 AT1G01030 {'pathway': 'auxin', 'pathwayID': 3}
# 1 AT3G17600 {'pathway': 'auxin', 'pathwayID': 3}
# 2 AT1G01140 {'pathway': 'unknown', 'pathwayID': 0}
# 3 AT2G23290 {'pathway': 'unknown', 'pathwayID': 0}
# 4 AT1G01360 {'pathway': 'abscisic acid', 'pathwayID': 1}
# 5 AT4G26080 {'pathway': 'unknown', 'pathwayID': 0}

# %% [markdown]
# ### Community Detection

# %%
# ORCCI for no side info and complete observation
orc_full, partitions_list = orcci(g, block_label="blockRicci", verbose="ERROR") # "INFO"
# Out:
# Using number of cpu threads: = 16
#
#
# FINAL RESULT
# ========================================================
# Elapsed time: 217.7631 (s)
# Number of iterations: 876
# Number of communities detected: 180
# Size of largest community: 63
# List of component sizes (final): [2 63 50 18 13 3 2 2 3 2 3 12 9 4 8 14 43 10 5 5 5 6 6 2 10 4 18 4 4 8 6 3 13 3 2 4 7 4 4 3 3 5 2 5 2 2 2 2 4 2 7 1 5 9 2 4 1 21 4 3 3 4 3 4 4 4 2 5 2 3 4 10 6 2 2 38 4 3 8 4 6 3 2 5 5 2 7 4 5 3 3 2 10 2 8 1 2 2 4 6 2 6 8 7 3 2 3 2 4 2 3 2 7 2 2 2 3 4 2 4 5 4 3 2 2 2 3 4 3 2 2 6 3 2 4 2 6 3 2 2 3 3 12 10 3 4 2 2 4 2 2 2 2 3 3 2 2 2 2 2 2 3 3 2 6 2 4 2 2 4 2 2 3 4 3 3 2 2 3 2]
# MAXIMUM MODULARITY PARTITION RESULT
# ========================================================
# Modularity: 0.5849
# Number of communities detected: 118
# List of component sizes (max mod): [2 102 88 18 47 6 3 16 5 33 6 10 14 43 10 11 5 5 9 2 13 50 4 4 19 7 23 3 5 2 13 2 1 5 1 21 4 3 4 6 4 10 6 2 2 4 3 6 2 5 5 2 7 9 7 3 10 2 1 2 4 12 7 2 16 2 3 2 2 2 4 2 5 7 6 2 2 3 3 2 2 6 3 2 2 18 3 2 2 3 10 4 2 2 4 2 2 2 2 3 3 2 2 2 2 2 2 3 2 2 4 2 2 4 2 2 4 2]

# %%
# output .gml filename creation
f_out = "../results/PhI_files/PhIFull/PhIFull.gml"

print(f_out)
nx.write_gml(orc_full.G,f_out,stringizer=str)
# Out:
# ../results/PhI_files/PhIFull/PhIFull.gml

# %%
g_orc = orc_full.G

print(nx.info(g_orc))

for idx, node in enumerate(g_orc.nodes()):
    print(idx, node, g_orc.nodes[node])
    if idx == 5:
        break
# Out:
# Name: Arabidopsis PPI
# Type: Graph
# Number of nodes: 925
# Number of edges: 2021
# Average degree:   4.3697
# 0 AT1G01030 {'pathway': 'auxin', 'pathwayID': 3, 'known': 0, 'blockRicciMaxMod': 0, 'blockRicciFinal': 0}
# 1 AT3G17600 {'pathway': 'auxin', 'pathwayID': 3, 'known': 0, 'blockRicciMaxMod': 1, 'blockRicciFinal': 1}
# 2 AT1G01140 {'pathway': 'unknown', 'pathwayID': 0, 'known': 0, 'blockRicciMaxMod': 2, 'blockRicciFinal': 2}
# 3 AT2G23290 {'pathway': 'unknown', 'pathwayID': 0, 'known': 0, 'blockRicciMaxMod': 1, 'blockRicciFinal': 1}
# 4 AT1G01360 {'pathway': 'abscisic acid', 'pathwayID': 1, 'known': 0, 'blockRicciMaxMod': 3, 'blockRicciFinal': 3}
# 5 AT4G26080 {'pathway': 'unknown', 'pathwayID': 0, 'known': 0, 'blockRicciMaxMod': 4, 'blockRicciFinal': 4}

# %% [markdown]
# #### Side Information

# %%
g_orc = orc_full.G

nodes_known = []

for node in g_orc:
    if g_orc.nodes[node]['pathway'] != 'unknown':
        nodes_known.append(node)
    print(node, g_orc.nodes[node]['pathway'])
# nodes_known
# Out:
# AT1G01030 auxin
# AT3G17600 auxin
# AT1G01140 unknown
# AT2G23290 unknown
# AT1G01360 abscisic acid
# AT4G26080 unknown
# AT1G04100 auxin
# AT1G15050 auxin
# AT2G33310 auxin
# AT3G04730 auxin
# AT3G16500 auxin
# AT3G23030 auxin
# AT4G14560 auxin
# AT1G04240 auxin
# AT1G04250 auxin
# AT3G15540 auxin
# AT1G04550 auxin
# AT1G07430 abscisic acid
# AT4G01026 abscisic acid
# AT4G18620 abscisic acid
# AT1G10940 auxin
# AT2G36270 abscisic acid
# AT3G23050 unknown
# AT1G15550 gibberellin
# AT5G60120 unknown
# AT1G17380 jasmonic acid
# AT3G29350 cytokinin
# AT4G28910 jasmonic acid
# AT1G18400 brassinosteroid
# AT5G41920 unknown
# AT1G19050 cytokinin
# AT1G22770 gibberellin
# AT1G51950 auxin
# AT2G37630 gibberellin
# AT2G44950 unknown
# AT4G08150 gibberellin
# AT4G32570 jasmonic acid
# AT4G37260 unknown
# AT1G25470 unknown
# AT5G08130 brassinosteroid
# AT1G30270 unknown
# AT5G47100 abscisic acid
# AT1G32640 unknown
# AT1G37130 salicylic acid
# AT5G18930 unknown
# AT1G50600 unknown
# AT2G20350 unknown
# AT1G51660 unknown
# AT3G24520 abscisic acid
# AT3G45640 salicylic acid
# AT3G61830 unknown
# AT1G52340 abscisic acid
# AT1G53170 ethylene
# AT5G19000 ethylene
# AT1G53510 unknown
# AT2G01570 gibberellin
# AT1G53910 unknown
# AT2G38490 unknown
# AT1G54490 ethylene
# AT1G64280 salicylic acid
# AT5G06950 salicylic acid
# AT1G64520 cytokinin
# AT1G65620 gibberellin
# AT1G73410 unknown
# AT1G75080 brassinosteroid
# AT2G30590 unknown
# AT2G42880 unknown
# AT3G14720 unknown
# AT4G16110 unknown
# AT2G01760 cytokinin
# AT2G46990 auxin
# AT3G62100 auxin
# AT4G00120 auxin
# AT2G02560 auxin
# AT2G25090 unknown
# AT5G53160 abscisic acid
# AT5G58950 ethylene
# AT5G67300 unknown
# AT2G25490 ethylene
# AT2G26980 abscisic acid
# AT2G28350 auxin
# AT2G29380 unknown
# AT5G45860 abscisic acid
# AT4G28640 auxin
# AT2G39220 unknown
# AT2G40330 abscisic acid
# AT3G48090 salicylic acid
# AT5G51760 abscisic acid
# AT3G04240 unknown
# AT3G28910 brassinosteroid
# AT5G17690 gibberellin
# AT4G30080 auxin
# AT4G11070 unknown
# AT4G24240 unknown
# AT5G61380 circadian rhythm
# AT5G64810 jasmonic acid
# AT4G14713 unknown
# AT4G15560 abscisic acid
# AT4G16420 auxin
# AT4G27920 abscisic acid
# AT5G05440 abscisic acid
# AT5G04870 salicylic acid
# AT5G06960 salicylic acid
# AT5G10930 unknown
# AT5G35410 unknown
# AT5G45820 abscisic acid
# AT5G58380 unknown
# AT1G78590 abscisic acid
# AT4G32010 unknown
# AT4G24470 unknown
# AT3G23610 unknown
# AT5G45810 unknown
# AT4G36930 unknown
# AT5G45830 abscisic acid
# AT1G35560 unknown
# AT4G00240 protein processing
# AT1G77200 unknown
# AT1G17550 unknown
# AT2G04550 unknown
# AT3G62340 unknown
# AT4G29810 auxin
# AT1G21690 dna repair
# AT3G57040 cytokinin
# AT5G62000 unknown
# AT2G46130 unknown
# AT4G24400 unknown
# AT1G19220 auxin
# AT5G55170 salicylic acid
# AT1G51600 unknown
# AT3G21175 unknown
# AT4G29800 unknown
# AT5G13080 unknown
# AT5G43290 unknown
# AT1G14280 auxin
# AT2G39250 unknown
# AT4G36540 brassinosteroid
# AT1G28360 ethylene
# AT3G01970 unknown
# AT1G10210 auxin
# AT1G18350 unknown
# AT1G07340 brassinosteroid
# AT3G15150 cytokinin
# AT1G80340 gibberellin
# AT2G30020 abscisic acid
# AT4G01370 unknown
# AT2G44050 jasmonic acid
# AT5G01810 abscisic acid
# AT1G74950 jasmonic acid
# AT1G50960 gibberellin
# AT3G54220 unknown
# AT1G31880 unknown
# AT2G44745 unknown
# AT5G55910 auxin
# AT1G69560 unknown
# AT1G66560 unknown
# AT5G22570 salicylic acid
# AT5G25190 ethylene
# AT3G12250 salicylic acid
# AT1G74910 ethylene
# AT3G03540 unknown
# AT1G14920 gibberellin
# AT3G03450 gibberellin
# AT5G54190 ethylene
# AT5G01600 salicylic acid
# AT1G72450 jasmonic acid
# AT2G24570 unknown
# AT1G68550 unknown
# AT4G02570 unknown
# AT5G13220 jasmonic acid
# AT1G77470 salicylic acid
# AT5G16080 unknown
# AT2G02950 auxin
# AT2G32960 unknown
# AT4G24210 gibberellin
# AT4G31920 cytokinin
# AT2G25000 salicylic acid
# AT5G57050 abscisic acid
# AT5G64813 ethylene
# AT4G26070 abscisic acid
# AT2G45820 ethylene
# AT3G44620 unknown
# AT4G27450 ethylene
# AT5G43830 ethylene
# AT1G19180 unknown
# AT1G70700 jasmonic acid
# AT2G46870 auxin
# AT1G22640 unknown
# AT1G69810 unknown
# AT1G80840 salicylic acid
# AT4G18880 unknown
# AT3G20550 ethylene
# AT5G56580 plant pathogen interaction
# AT4G14720 jasmonic acid
# AT1G63160 dna repair
# AT5G04190 auxin
# AT1G06400 auxin
# AT4G17720 ethylene
# AT1G23860 ethylene
# AT3G61860 ethylene
# AT5G59220 abscisic acid
# AT2G34650 auxin
# AT5G40440 jasmonic acid
# AT1G69010 brassinosteroid
# AT5G38860 brassinosteroid
# AT4G39780 ethylene
# AT5G21010 ethylene
# AT2G43790 unknown
# AT2G40750 salicylic acid
# AT4G26110 abscisic acid
# AT1G25490 unknown
# AT5G11270 jasmonic acid
# AT3G52930 ethylene
# AT5G03690 dna rna metabolism
# AT5G65210 salicylic acid
# AT2G39760 ethylene
# AT5G25890 auxin
# AT1G30135 jasmonic acid
# AT5G67000 unknown
# AT3G42960 brassinosteroid
# AT5G58220 brassinosteroid
# AT2G26560 unknown
# AT3G63210 abscisic acid
# AT1G54990 auxin
# AT2G38120 auxin
# AT2G04890 unknown
# AT3G17510 abscisic acid
# AT2G30980 brassinosteroid
# AT4G18890 brassinosteroid
# AT1G24590 brassinosteroid
# AT1G22070 salicylic acid
# AT1G75000 unknown
# AT5G05730 unknown
# AT4G33790 fatty acid metabolism
# AT5G48870 abscisic acid
# AT1G13980 auxin
# AT3G11410 abscisic acid
# AT5G20900 jasmonic acid
# AT5G17490 gibberellin
# AT5G05410 unknown
# AT2G22090 abscisic acid
# AT4G33520 unknown
# AT5G07310 unknown
# AT5G48150 unknown
# AT3G25890 unknown
# AT5G13930 auxin
# AT1G35540 unknown
# AT2G38310 abscisic acid
# AT2G33830 auxin
# AT3G03530 unknown
# AT2G18170 signal transduction
# AT5G01820 salicylic acid
# AT5G24860 gibberellin
# AT1G14687 unknown
# AT3G22660 unknown
# AT1G71230 auxin
# AT2G47880 unknown
# AT5G48470 unknown
# AT1G28480 unknown
# AT2G25650 unknown
# AT5G52040 ethylene
# AT3G54810 unknown
# AT4G03420 unknown
# AT5G14250 unknown
# AT5G24660 unknown
# AT2G30360 unknown
# AT3G21220 ethylene
# AT1G51100 unknown
# AT4G12020 unknown
# AT3G01670 unknown
# AT1G75950 protein processing
# AT1G56160 ethylene
# AT1G77920 unknown
# AT2G34900 abscisic acid
# AT1G15200 rna processing
# AT1G02690 unknown
# AT1G19010 unknown
# AT5G16400 unknown
# AT3G13672 protein processing
# AT5G59730 unknown
# AT1G66160 unknown
# AT3G02140 abscisic acid
# AT5G39340 unknown
# AT4G17615 abscisic acid
# AT2G17670 unknown
# AT5G42900 unknown
# AT2G44840 ethylene
# AT3G05000 unknown
# AT4G16143 unknown
# AT4G02150 unknown
# AT5G37055 unknown
# AT5G61010 unknown
# AT4G31300 unknown
# AT5G62520 unknown
# AT5G14070 unknown
# AT5G61230 unknown
# AT4G25670 unknown
# AT5G45680 unknown
# AT3G52120 unknown
# AT4G18040 unknown
# AT3G50670 unknown
# AT1G09500 unknown
# AT3G05640 unknown
# AT5G49210 unknown
# AT2G33430 unknown
# AT3G60360 unknown
# AT3G19120 unknown
# AT2G42260 unknown
# AT5G49690 unknown
# AT3G18210 unknown
# AT5G14170 unknown
# AT3G06430 unknown
# AT3G01690 unknown
# AT1G51580 unknown
# AT2G32650 unknown
# AT3G18140 unknown
# AT4G18372 unknown
# AT4G23910 unknown
# AT3G55150 unknown
# AT4G09650 unknown
# AT3G21150 unknown
# AT5G22890 unknown
# AT1G13690 unknown
# AT4G39410 unknown
# AT4G15770 unknown
# AT4G25470 unknown
# AT1G07210 unknown
# AT3G12830 unknown
# AT3G17668 unknown
# AT5G48335 unknown
# AT5G62770 unknown
# AT3G50910 unknown
# AT5G44420 unknown
# AT1G06460 unknown
# AT5G05790 unknown
# AT3G49810 unknown
# AT3G57720 unknown
# AT2G39100 unknown
# AT3G13200 rna processing
# AT4G02770 unknown
# AT1G67090 unknown
# AT1G02140 rna processing
# AT3G11850 unknown
# AT3G30210 abscisic acid
# AT2G43370 unknown
# AT1G77710 unknown
# AT4G20300 unknown
# AT5G20920 rna processing
# AT4G28860 unknown
# AT4G18700 unknown
# AT1G56170 unknown
# AT2G46790 unknown
# AT5G63470 unknown
# AT2G25250 unknown
# AT1G09810 unknown
# AT1G54200 unknown
# AT3G02460 unknown
# AT1G76890 unknown
# AT3G48510 unknown
# AT4G18830 unknown
# AT5G25510 unknown
# AT1G10650 unknown
# AT1G21600 unknown
# AT3G57730 unknown
# AT2G32180 unknown
# AT2G27020 unknown
# AT1G03130 unknown
# AT2G25880 unknown
# AT1G72670 unknown
# AT5G25280 unknown
# AT5G27720 rna processing
# AT4G09060 unknown
# AT3G62550 unknown
# AT1G79650 protein processing
# AT4G22720 unknown
# AT4G05450 unknown
# AT2G35940 unknown
# AT4G00780 unknown
# AT5G18580 unknown
# AT5G59450 unknown
# AT2G31955 unknown
# AT5G23130 unknown
# AT3G18240 unknown
# AT5G04820 unknown
# AT3G14080 rna processing
# AT3G53250 auxin
# AT5G25580 unknown
# AT1G68590 unknown
# AT5G12190 rna processing
# AT3G06790 unknown
# AT5G28770 unknown
# AT3G58680 unknown
# AT5G39950 unknown
# AT1G61150 unknown
# AT5G57950 unknown
# AT5G60890 jasmonic acid
# AT5G65683 unknown
# AT4G00180 unknown
# AT1G05510 unknown
# AT4G18010 abscisic acid
# AT3G48680 unknown
# AT4G20130 unknown
# AT5G50230 unknown
# AT5G42970 unknown
# AT5G55620 unknown
# AT3G08710 unknown
# AT1G64000 unknown
# AT2G22880 unknown
# AT4G33925 unknown
# AT2G41680 unknown
# AT3G13740 unknown
# AT3G48150 protein processing
# AT1G29260 fatty acid metabolism
# AT1G01225 unknown
# AT3G17090 unknown
# AT5G08480 unknown
# AT4G37710 unknown
# AT1G76080 unknown
# AT2G33150 unknown
# AT1G60950 unknown
# AT5G51940 rna processing
# AT1G80940 unknown
# AT3G18430 unknown
# AT4G36030 unknown
# AT3G56090 unknown
# AT3G03270 unknown
# AT5G49620 abscisic acid
# AT2G29540 rna processing
# AT5G64150 unknown
# AT1G68160 unknown
# AT1G80370 unknown
# AT1G05730 unknown
# AT3G51030 unknown
# AT3G22810 unknown
# AT1G51090 unknown
# AT5G50680 protein processing
# AT5G14600 unknown
# AT4G18650 unknown
# AT2G46900 unknown
# AT1G50170 unknown
# AT3G60630 unknown
# AT1G72030 unknown
# AT5G11980 unknown
# AT2G33610 unknown
# AT3G56270 unknown
# AT1G62520 unknown
# AT2G32840 unknown
# AT1G05860 unknown
# AT2G01620 unknown
# AT3G07090 unknown
# AT4G38630 abscisic acid
# AT1G50420 unknown
# AT4G22220 unknown
# AT4G28880 unknown
# AT3G52155 unknown
# AT1G20780 abscisic acid
# AT5G03050 unknown
# AT1G17650 unknown
# AT1G31240 unknown
# AT5G52210 unknown
# AT5G23750 unknown
# AT3G57870 protein processing
# AT1G16705 unknown
# AT2G20610 auxin
# AT5G37478 unknown
# AT1G63090 unknown
# AT5G07260 unknown
# AT1G12120 unknown
# AT4G26610 unknown
# AT1G63480 unknown
# AT4G30860 unknown
# AT5G03520 protein processing
# AT5G47200 unknown
# AT3G46060 ethylene
# AT4G18800 protein processing
# AT1G55190 unknown
# AT5G22310 unknown
# AT3G11400 rna processing
# AT5G03740 abscisic acid
# AT5G50180 unknown
# AT1G49850 unknown
# AT1G05710 unknown
# AT3G15660 unknown
# AT5G59490 unknown
# AT5G41070 unknown
# AT3G54170 unknown
# AT1G01210 rna processing
# AT2G27840 unknown
# AT5G05190 unknown
# AT3G27580 unknown
# AT5G19340 unknown
# AT3G18295 unknown
# AT1G03330 rna processing
# AT4G22745 unknown
# AT1G03900 unknown
# AT5G18110 rna processing
# AT4G31050 unknown
# AT1G68130 unknown
# AT5G11460 unknown
# AT4G03250 unknown
# AT2G35010 unknown
# AT1G23220 unknown
# AT1G10760 unknown
# AT1G14685 unknown
# AT4G14020 unknown
# AT4G39540 unknown
# AT4G21660 rna processing
# AT3G16560 unknown
# AT1G76070 unknown
# AT5G58960 unknown
# AT1G20140 protein processing
# AT3G12720 unknown
# AT5G57860 unknown
# AT2G39770 jasmonic acid
# AT3G23240 unknown
# AT4G17680 unknown
# AT1G15570 unknown
# AT4G32660 unknown
# AT4G31800 salicylic acid
# AT5G42980 unknown
# AT2G16030 unknown
# AT4G21450 unknown
# AT1G07350 unknown
# AT5G04430 ethylene
# AT5G46190 unknown
# AT5G52650 protein processing
# AT5G38410 unknown
# AT5G64960 unknown
# AT3G57290 unknown
# AT4G37470 unknown
# AT1G05410 unknown
# AT3G54850 unknown
# AT3G05420 ethylene
# AT3G21215 unknown
# AT1G72360 ethylene
# AT1G68450 unknown
# AT5G41570 unknown
# AT4G21560 protein processing
# AT1G73060 unknown
# AT3G59910 unknown
# AT1G18660 unknown
# AT2G04630 rna processing
# AT4G12100 protein processing
# AT1G01630 unknown
# AT5G10710 unknown
# AT5G27630 unknown
# AT5G43820 unknown
# AT3G49060 unknown
# AT1G77950 unknown
# AT3G16980 rna processing
# AT2G44740 unknown
# AT1G11810 unknown
# AT1G56590 unknown
# AT3G02000 unknown
# AT1G80720 unknown
# AT3G07300 rna processing
# AT4G02485 unknown
# AT3G47910 unknown
# AT2G34590 metabolism
# AT5G47830 unknown
# AT5G08290 ethylene
# AT3G12210 unknown
# AT5G67520 amino acid metabolism
# AT3G50800 unknown
# AT5G64180 unknown
# AT1G56450 unknown
# AT3G28710 unknown
# AT3G51130 unknown
# AT2G23760 unknown
# AT4G18060 unknown
# AT1G50710 unknown
# AT2G28000 unknown
# AT5G22480 unknown
# AT2G21630 protein processing
# AT3G15650 unknown
# AT5G62600 unknown
# AT5G60690 unknown
# AT3G01990 unknown
# AT2G47450 unknown
# AT1G01260 unknown
# AT3G09370 unknown
# AT3G58380 unknown
# AT3G29090 unknown
# AT1G54380 rna processing
# AT3G18960 unknown
# AT1G54830 unknown
# AT2G25010 unknown
# AT4G13260 auxin
# AT5G11010 unknown
# AT3G15450 unknown
# AT4G14710 amino acid metabolism
# AT3G29370 unknown
# AT4G14716 amino acid metabolism
# AT4G38850 auxin
# AT5G02760 unknown
# AT2G24090 protein processing
# AT1G77770 unknown
# AT2G38270 unknown
# AT5G27690 unknown
# AT5G52010 unknown
# AT2G18730 signal transduction
# AT1G12860 unknown
# AT1G30880 unknown
# AT3G29770 unknown
# AT1G09700 abscisic acid
# AT3G54130 unknown
# AT5G05690 brassinosteroid
# AT1G18710 jasmonic acid
# AT3G50330 unknown
# AT5G52547 unknown
# AT3G56910 unknown
# AT1G08580 unknown
# AT2G43060 unknown
# AT3G06590 unknown
# AT3G62870 protein processing
# AT1G50670 protein processing
# AT3G22490 unknown
# AT4G19200 unknown
# AT4G33950 abscisic acid
# AT5G39360 unknown
# AT4G35620 unknown
# AT4G14160 protein processing
# AT5G17710 unknown
# AT2G35900 unknown
# AT1G51520 unknown
# AT1G11430 unknown
# AT1G53000 unknown
# AT5G13180 unknown
# AT2G30540 unknown
# AT3G02090 unknown
# AT4G15670 unknown
# AT3G44610 unknown
# AT4G17490 ethylene
# AT1G04710 abscisic acid
# AT3G04300 unknown
# AT4G17500 unknown
# AT5G41650 unknown
# AT4G33460 unknown
# AT1G80780 rna processing
# AT4G37580 ethylene
# AT5G27560 unknown
# AT4G11140 unknown
# AT4G18630 unknown
# AT2G38300 unknown
# AT3G59810 rna processing
# AT3G13720 unknown
# AT3G53710 ethylene
# AT5G17300 unknown
# AT5G24520 jasmonic acid
# AT2G41710 unknown
# AT2G45640 abscisic acid
# AT3G27560 unknown
# AT2G42750 unknown
# AT2G24860 unknown
# AT5G67220 unknown
# AT3G43440 jasmonic acid
# AT3G56900 unknown
# AT1G17980 unknown
# AT1G06180 unknown
# AT3G23060 unknown
# AT5G23710 rna processing
# AT5G57685 salicylic acid
# AT5G18260 unknown
# AT2G30120 unknown
# AT2G33860 auxin
# AT1G67340 unknown
# AT2G32460 unknown
# AT5G05360 unknown
# AT1G71260 unknown
# AT1G76680 salicylic acid
# AT3G63260 unknown
# AT5G43650 unknown
# AT5G14750 unknown
# AT2G03710 unknown
# AT2G32600 unknown
# AT5G65300 unknown
# AT4G37240 unknown
# AT2G36145 unknown
# AT5G07690 unknown
# AT1G35210 unknown
# AT5G06770 unknown
# AT1G48450 unknown
# AT3G19820 brassinosteroid
# AT1G03457 unknown
# AT2G38610 unknown
# AT1G54080 unknown
# AT3G19130 unknown
# AT1G27650 rna processing
# AT2G16940 unknown
# AT2G17190 protein processing
# AT2G35635 auxin
# AT5G63670 unknown
# AT1G03860 unknown
# AT3G07670 unknown
# AT2G37560 unknown
# AT1G76420 unknown
# AT4G25740 protein processing
# AT5G15802 unknown
# AT4G32295 unknown
# AT3G46630 unknown
# AT5G18020 auxin
# AT1G66370 jasmonic acid
# AT1G01560 abscisic acid
# AT1G08780 unknown
# AT5G54580 unknown
# AT3G58650 unknown
# AT5G42050 unknown
# AT3G49950 unknown
# AT3G24730 unknown
# AT1G12840 unknown
# AT2G05170 unknown
# AT5G51100 unknown
# AT5G25340 unknown
# AT1G53230 unknown
# AT2G22670 auxin
# AT2G24590 rna processing
# AT1G20910 unknown
# AT2G26010 unknown
# AT5G22290 unknown
# AT1G30500 unknown
# AT1G21200 unknown
# AT3G54390 unknown
# AT1G59580 signal transduction
# AT2G45680 unknown
# AT5G23280 unknown
# AT1G48630 abscisic acid
# AT5G53210 unknown
# AT2G02540 unknown
# AT2G40620 unknown
# AT4G14550 auxin
# AT1G69690 unknown
# AT3G63010 gibberellin
# AT1G22490 unknown
# AT4G35580 unknown
# AT2G22760 unknown
# AT4G16780 cytokinin
# AT5G08070 unknown
# AT3G44350 unknown
# AT1G34180 unknown
# AT3G02150 unknown
# AT3G59790 auxin
# AT3G62610 unknown
# AT5G43700 auxin
# AT4G32980 gibberellin
# AT2G16400 unknown
# AT4G02590 unknown
# AT2G28910 unknown
# AT4G24650 cytokinin
# AT4G00870 unknown
# AT1G52830 auxin
# AT4G17785 unknown
# AT2G20110 unknown
# AT1G70030 unknown
# AT5G51910 unknown
# AT2G31310 unknown
# AT2G38250 unknown
# AT2G39200 unknown
# AT5G05700 abscisic acid
# AT5G39820 unknown
# AT2G35320 unknown
# AT2G36340 unknown
# AT1G34670 unknown
# AT3G28470 brassinosteroid
# AT4G01550 unknown
# AT1G15580 auxin
# AT1G06170 unknown
# AT4G34990 unknown
# AT1G54060 unknown
# AT2G43220 unknown
# AT1G12890 unknown
# AT4G04885 unknown
# AT1G22985 unknown
# AT3G54350 unknown
# AT1G07530 salicylic acid
# AT2G02160 unknown
# AT1G59940 cytokinin
# AT1G76870 unknown
# AT5G62920 cytokinin
# AT2G41310 cytokinin
# AT1G74890 cytokinin
# AT2G40670 cytokinin
# AT3G15210 unknown
# AT1G23420 unknown
# AT1G68670 unknown
# AT3G25790 unknown
# AT3G12910 unknown
# AT3G45150 unknown
# AT1G25550 unknown
# AT5G08330 unknown
# AT3G57600 unknown
# AT2G45190 unknown
# AT2G20880 unknown
# AT1G21970 abscisic acid
# AT5G18560 auxin
# AT5G18240 unknown
# AT4G13640 unknown
# AT1G68510 unknown
# AT3G51180 unknown
# AT1G72210 unknown
# AT3G27810 unknown
# AT2G47700 unknown
# AT5G41410 unknown
# AT5G44210 ethylene
# AT1G03800 ethylene
# AT1G28370 ethylene
# AT2G30340 unknown
# AT1G31320 unknown
# AT3G13960 unknown
# AT5G47790 unknown
# AT4G18710 brassinosteroid
# AT3G58630 unknown
# AT4G17880 unknown
# AT5G41315 unknown
# AT2G27110 unknown
# AT3G17860 jasmonic acid
# AT2G34600 jasmonic acid
# AT1G02450 unknown
# AT1G24230 unknown
# AT3G25882 unknown
# AT1G09415 unknown
# AT2G31720 unknown
# AT4G29080 auxin
# AT1G80390 auxin
# AT5G60142 unknown
# AT5G09250 unknown
# AT5G65670 auxin
# AT2G01200 auxin
# AT3G23250 unknown
# AT3G50890 unknown
# AT3G28917 unknown
# AT5G57420 auxin
# AT1G75340 rna processing
# AT4G32280 auxin
# AT1G35240 unknown
# AT3G21330 unknown
# AT5G66350 gibberellin
# AT1G19700 unknown
# AT3G47620 unknown
# AT5G16560 unknown
# AT2G46735 unknown
# AT1G66350 gibberellin
# AT1G76900 unknown
# AT2G36990 unknown
# AT5G50570 unknown
# AT5G25220 cytokinin
# AT5G50670 unknown
# AT5G54070 unknown
# AT2G26800 fatty acid metabolism
# AT3G29270 unknown
# AT3G49580 unknown
# AT5G02150 protein processing
# AT4G22250 unknown
# AT3G51630 unknown
# AT4G26455 unknown
# AT5G51440 unknown
# AT1G72770 abscisic acid
# AT4G23050 unknown
# AT1G72340 rna processing
# AT2G31070 unknown
# AT3G07740 unknown
# AT3G58030 unknown
# AT3G50060 auxin
# AT5G49330 unknown
# AT3G18550 unknown
# AT4G22070 unknown
# AT1G12980 unknown
# AT2G30470 abscisic acid
# AT4G29120 fatty acid metabolism
# AT5G02810 unknown
# AT4G20930 fatty acid metabolism
# AT2G44680 unknown
# AT1G69850 unknown
# AT5G45870 abscisic acid
# AT5G46590 unknown
# AT2G42490 unknown
# AT5G05330 unknown
# AT1G33050 unknown
# AT5G13810 unknown
# AT1G24280 unknown
# AT2G46550 unknown
# AT5G28900 unknown
# AT1G06510 unknown
# AT4G17870 abscisic acid
# AT5G46790 abscisic acid
# AT1G73000 abscisic acid
# AT2G26040 abscisic acid
# AT5G45110 unknown
# AT5G58800 unknown
# AT1G15750 auxin
# AT4G19660 unknown
# AT1G12810 unknown
# AT3G08530 protein processing
# AT2G19080 unknown
# AT5G06320 unknown
# AT5G22270 unknown
# AT4G24840 unknown
# AT4G27070 unknown
# AT3G05120 gibberellin
# AT3G10870 unknown
# AT5G27320 gibberellin
# AT1G20950 dna rna metabolism
# AT1G30120 metabolism
# AT3G02700 unknown
# AT4G16447 unknown
# AT2G42620 auxin
# AT5G42190 protein processing
# AT2G37410 unknown
# AT4G03415 unknown
# AT4G26660 unknown
# AT4G38580 unknown
# AT3G44110 protein processing
# AT1G09270 unknown
# AT1G48930 unknown
# AT5G09480 unknown
# AT3G25800 unknown
# AT3G01090 unknown
# AT1G02816 unknown
# AT2G43610 dna rna metabolism
# AT4G00060 unknown
# AT3G47820 unknown
# AT1G72800 unknown
# AT3G03990 unknown
# AT3G62980 auxin
# AT4G29700 unknown
# AT1G12820 auxin
# AT4G24390 unknown

# %%
# f_in = "../results/PhI_files/PhIFull/PhIFull.gml"
# print(f_in)

orc_sinfo, partitions_list = orcci(g_orc, nodes_known=nodes_known, block_label="blockRicciSinfo", sinfo_label="pathwayID", verbose="ERROR")
# Out:
# Using number of cpu threads: = 16
#
#
# FINAL RESULT
# ========================================================
# Elapsed time: 220.1696 (s)
# Number of iterations: 687
# Number of communities detected: 200
# Size of largest community: 64
# List of component sizes (final): [64 51 61 1 1 60 3 57 3 10 4 4 12 8 4 5 6 2 2 13 4 4 14 9 4 3 2 2 4 7 4 4 4 4 2 5 2 41 1 1 4 1 2 4 1 22 4 3 4 4 11 2 4 4 2 5 2 3 6 2 2 5 2 2 4 1 2 4 3 1 2 1 4 8 2 1 7 1 1 1 1 2 1 2 4 8 1 1 2 7 2 1 2 2 5 1 2 4 2 2 2 2 4 2 4 5 4 3 5 2 2 2 3 2 1 2 6 3 1 2 1 1 5 2 3 1 2 2 3 3 13 10 3 1 1 1 4 1 1 1 2 1 2 1 1 1 4 1 1 2 1 2 1 1 1 1 2 3 3 1 1 2 2 2 1 1 2 1 3 3 2 6 1 2 1 4 2 2 4 2 2 10 4 1 4 1 1 4 1 1 1 1 1 1 1 3 1 1 4 2]
# MAXIMUM MODULARITY PARTITION RESULT
# ========================================================
# Modularity: 0.5517
# Number of communities detected: 161
# List of component sizes (max mod): [115 92 72 1 1 66 3 78 5 35 6 12 4 5 10 2 2 4 4 17 2 4 7 13 12 2 7 1 1 1 1 22 7 4 4 11 6 3 6 2 2 2 1 2 4 3 1 2 1 4 8 2 1 7 1 1 1 1 1 2 4 8 1 1 7 2 1 1 2 2 2 2 4 2 5 7 5 2 2 2 3 2 1 2 6 3 1 2 1 1 2 3 1 2 2 3 3 13 10 1 1 1 4 1 1 1 2 1 2 1 1 1 4 1 1 2 1 2 1 1 1 1 2 3 3 1 1 2 2 2 1 1 2 1 3 2 1 2 1 4 2 2 4 2 2 1 4 1 1 4 1 1 1 1 1 1 1 1 1 4 2]

# %%
g_orc = orc_sinfo.G

print(nx.info(g_orc))

for idx, node in enumerate(g_orc.nodes()):
    print(idx, node, g_orc.nodes[node])
    if idx == 5:
        break
# Out:
# Name: Arabidopsis PPI
# Type: Graph
# Number of nodes: 925
# Number of edges: 2021
# Average degree:   4.3697
# 0 AT1G01030 {'pathway': 'auxin', 'pathwayID': 3, 'known': 1, 'blockRicciMaxMod': 0, 'blockRicciFinal': 0, 'blockRicciSinfoMaxMod': 0, 'blockRicciSinfoFinal': 0}
# 1 AT3G17600 {'pathway': 'auxin', 'pathwayID': 3, 'known': 1, 'blockRicciMaxMod': 1, 'blockRicciFinal': 1, 'blockRicciSinfoMaxMod': 0, 'blockRicciSinfoFinal': 0}
# 2 AT1G01140 {'pathway': 'unknown', 'pathwayID': 0, 'known': 0, 'blockRicciMaxMod': 2, 'blockRicciFinal': 2, 'blockRicciSinfoMaxMod': 1, 'blockRicciSinfoFinal': 1}
# 3 AT2G23290 {'pathway': 'unknown', 'pathwayID': 0, 'known': 0, 'blockRicciMaxMod': 1, 'blockRicciFinal': 1, 'blockRicciSinfoMaxMod': 0, 'blockRicciSinfoFinal': 0}
# 4 AT1G01360 {'pathway': 'abscisic acid', 'pathwayID': 1, 'known': 1, 'blockRicciMaxMod': 3, 'blockRicciFinal': 3, 'blockRicciSinfoMaxMod': 2, 'blockRicciSinfoFinal': 2}
# 5 AT4G26080 {'pathway': 'unknown', 'pathwayID': 0, 'known': 0, 'blockRicciMaxMod': 4, 'blockRicciFinal': 4, 'blockRicciSinfoMaxMod': 2, 'blockRicciSinfoFinal': 2}

# %%
# output .gml filename creation
f_out = "../results/PhI_files/PhIFull/PhIFull_sinfo.gml"

print(f_out)
nx.write_gml(orc_sinfo.G,f_out,stringizer=str)
# Out:
# ../results/PhI_files/PhIFull/PhIFull_sinfo.gml
